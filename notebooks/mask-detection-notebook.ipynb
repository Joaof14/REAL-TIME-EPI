# %% [markdown]
# # YOLOv8 mask-detection
# Esse notebook foi produzido no ambiente do kaggle e está aqui com o objetivo de apenas demonstrar o que lá foi produzido

# %%
# !pip install -U ultralytics
# !wandb disabled
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:0000:01
# ...
# W&B disabled.

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(data='/kaggle/input/datasets/guilhermef2k/facemaskv1/data.yaml', epochs = 100, seed = 42)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
